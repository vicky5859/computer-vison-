# %% [markdown]
# <a href="https://colab.research.google.com/github/vicky5859/computer-vison-/blob/main/EX%3A30%20Morphological%20operations%20based%20on%20OpenCV%20using%20Dilation%20technique.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Dilation
dilation = cv2.dilate(gray, kernel, iterations=1)

plt.figure(figsize=(10, 4))

plt.subplot(1, 2, 1)
plt.imshow(gray, cmap='gray')
plt.title("Original")
plt.axis("off")

plt.subplot(1, 2, 2)
plt.imshow(dilation, cmap='gray')
plt.title("Dilation")
plt.axis("off")

plt.show()

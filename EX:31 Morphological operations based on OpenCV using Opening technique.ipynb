# %% [markdown]
# <a href="https://colab.research.google.com/github/vicky5859/computer-vison-/blob/main/EX%3A31%20Morphological%20operations%20based%20on%20OpenCV%20using%20Opening%20technique.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Opening = Erosion followed by Dilation
opening = cv2.morphologyEx(gray, cv2.MORPH_OPEN, kernel)

plt.figure(figsize=(10, 4))

plt.subplot(1, 2, 1)
plt.imshow(gray, cmap='gray')
plt.title("Original")
plt.axis("off")

plt.subplot(1, 2, 2)
plt.imshow(opening, cmap='gray')
plt.title("Opening")
plt.axis("off")

plt.show()

# %% [markdown]
# <a href="https://colab.research.google.com/github/vicky5859/computer-vison-/blob/main/EX%3A28.%20Find%20the%20boundary%20of%20the%20image%20using%20Convolution%20kernel%20for%20the%20given%20image.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# EXPERIMENT 28
# Finding Boundary using Convolution Kernel

import cv2
import numpy as np
import matplotlib.pyplot as plt
from google.colab import files

# Upload image
uploaded = files.upload()
filename = next(iter(uploaded))

# Read image in grayscale
img = cv2.imread(filename, cv2.IMREAD_GRAYSCALE)

# Laplacian convolution kernel
kernel = np.array([
    [-1, -1, -1],
    [-1,  8, -1],
    [-1, -1, -1]
])

# Apply convolution
boundary = cv2.filter2D(img, -1, kernel)

# Convert to absolute values
boundary = cv2.convertScaleAbs(boundary)

# Display
plt.figure(figsize=(12, 5))

plt.subplot(1, 2, 1)
plt.imshow(img, cmap='gray')
plt.title("Original Image")
plt.axis("off")

plt.subplot(1, 2, 2)
plt.imshow(boundary, cmap='gray')
plt.title("Boundary using Convolution Kernel")
plt.axis("off")

plt.show()
# Out:
#      <input type="file" id="files-846054f8-6a60-410a-944d-8705a24a2269" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-846054f8-6a60-410a-944d-8705a24a2269">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...
